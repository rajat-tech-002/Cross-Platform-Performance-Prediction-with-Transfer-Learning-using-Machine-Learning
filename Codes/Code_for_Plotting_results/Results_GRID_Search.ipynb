# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import pyplot
import numpy as np
import matplotlib as mpl
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 15}

mpl.rc('font', **font)

# %%
df = pd.read_csv('\\Results_CSV\\Results_1 - Grid Search without and with.csv')

# %%
df.head()
# Out:
#         Algo                                                 R2  \
# 0   SVR(w/t)  [-0.0658311807634937, -0.12969510199832168, -0...
# 1     SVR(w)  [0.13377133309085687, 0.03088757029316347, 0.1...
# 2    LR(w/t)  [0.8123341484661075, 0.8833666419290108, 0.923...
# 3      LR(w)  [0.8123341484661075, 0.8833666419290108, 0.923...
# 4   GPR(w/t)  [0.7199102680513079, 0.12197138485272219, 0.77...
#
#                                                  MSE  \
# 0  [922076820.4108654, 1692109327.7685883, 417031...
# 1  [749395766.7481322, 1451581209.0029356, 324036...
# 2  [95072809.04342937, 165189796.50579256, 681662...
# 3  [95072809.04342937, 165189796.50579256, 681662...
# 4  [141895381.51417032, 1243566769.0727196, 20451...
#
#                                               MedAPE
# 0  [0.2870987973390742, 0.3361596542249228, 0.246...
# 1  [0.22622585613911664, 0.27469456583603985, 0.1...
# 2  [0.19899853250688684, 0.16776634478004782, 0.1...
# 3  [0.19899853250688684, 0.16776634478004782, 0.1...
# 4  [0.21882587146644417, 0.2634201974573304, 0.17...

# %%
ls  = df['Algo']
ls
# Out:
# 0     SVR(w/t)
# 1       SVR(w)
# 2      LR(w/t)
# 3        LR(w)
# 4     GPR(w/t)
# 5       GPR(w)
# 6     KNN(w/t)
# 7      KNN(w)
# Name: Algo, dtype: object

# %%
df.iloc[0]['R2']
# Out:
# '[-0.0658311807634937, -0.12969510199832168, -0.08527278470992972, -0.10941952396659871, -0.25124907574289845, -0.1420410843128388, -0.13382856516407404, -0.11509726445623136, -0.11011006194310657, -0.12147245748361324]'

# %%
def convert_to_num(arr, ind):
    # print(arr[ind])
    arr = arr[ind]
    arr = [float(s) for s in arr[1:-1].split(',')]
    # print(arr)
    return arr

# %%
def convert_to_num_mape(arr, ind):
    # print(arr[ind])
    arr = arr[ind]
    arr = [float(s) for s in arr[1:-1].split(',')]
    arr = [x*100 for x in arr]
    # print(arr)
    return arr

# %%
x = ls
y1 = []
for i in range(8):
    # x = [ls[0], ls[1]]
    a = convert_to_num(df[df['Algo'] ==ls[i]]['R2'], ind = i)
    # b = convert_to_num(df[df['Algo'] == ls[1]]['R2'], ind = 1)
    # y = [a, b ]
    y1.append(a)
plt.boxplot(y1, labels = x)
plt.xlabel('Models with and without GS')
plt.ylabel('R2 score')
plt.title('Comparison of R2 scores')
plt.xticks(rotation = 45)
# plt.savefig('Results_1.jpg')
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]), <a list of 8 Text xticklabel objects>)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
x = ls
y2 = []
for i in range(8):
    # x = [ls[0], ls[1]]
    a = convert_to_num_mape(df[df['Algo'] ==ls[i]]['MedAPE'], ind = i)
    # b = convert_to_num(df[df['Algo'] == ls[1]]['R2'], ind = 1)
    # y = [a, b ]
    y2.append(a)
plt.boxplot(y2, labels = x)
plt.xlabel('Models with and without GS')
plt.ylabel('MedAPE score')
plt.title('Comparison of MedAPE scores')
plt.xticks(rotation = 45)
# plt.savefig('Results_1.jpg')
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]), <a list of 8 Text xticklabel objects>)

# %%
x = ls
y3 = []
for i in range(8):
    # x = [ls[0], ls[1]]
    a = convert_to_num(df[df['Algo'] ==ls[i]]['MSE'], ind = i)
    # b = convert_to_num(df[df['Algo'] == ls[1]]['R2'], ind = 1)
    # y = [a, b ]
    y3.append(a)
plt.boxplot(y3, labels = x)
plt.xlabel('Models with and without GS')
plt.ylabel('MSE score')
plt.title('Comparison of MSE scores')
plt.xticks(rotation = 45)
# plt.savefig('Results_1.jpg')
# Out:
# (array([1, 2, 3, 4, 5, 6, 7, 8]), <a list of 8 Text xticklabel objects>)

# %%
y1
# Out:
# [[-0.0658311807634937,
#   -0.12969510199832168,
#   -0.08527278470992972,
#   -0.10941952396659871,
#   -0.25124907574289845,
#   -0.1420410843128388,
#   -0.13382856516407404,
#   -0.11509726445623136,
#   -0.11011006194310657,
#   -0.12147245748361324],
#  [0.13377133309085687,
#   0.03088757029316347,
#   0.15673516994986125,
#   0.1308791251703295,
#   -0.040487914527084,
#   0.01155018329424895,
#   0.022828253963892986,
#   0.07771919827926288,
#   0.042925364798443666,
#   0.07828910687815394],
#  [0.8123341484661075,
#   0.8833666419290108,
#   0.9239536612745525,
#   0.8602039785187706,
#   0.8969485616280132,
#   0.9089315883533997,
#   0.8976931078253088,
#   0.7178100612680081,
#   0.8545420742982517,
#   0.8786228417311044],
#  [0.8123341484661075,
#   0.8833666419290108,
#   0.9239536612745525,
#   0.8602039785187706,
#   0.8969485616280132,
#   0.9089315883533997,
#   0.8976931078253088,
#   0.7178100612680081,
#   0.8545420742982517,
#   0.8786228417311044],
#  [0.7199102680513079,
#   0.12197138485272219,
#   0.7718461120300597,
#   0.7813454284413012,
#   0.9220420852534217,
#   0.8698078170156298,
#   0.8071042495145165,
#   0.16358369231971537,
#   0.6908220035965412,
#   0.7594391702530074],
#  [0.927565975029965,
#   0.665954390355997,
#   0.9170413558678924,
#   0.942520282501753,
#   0.9783890499193192,
#   0.968072402922825,
#   0.8959234797032439,
#   0.831016214996932,
#   0.8835359753379018,
#   0.8776533894259955],
#  [0.8764830259387708,
#   0.76517885115347,
#   0.9031163549909937,
#   0.9310655181042253,
#   0.9645368623608084,
#   0.9426795908609095,
#   0.961306461866837,
#   0.7321977279599239,
#   0.9107661180134172,
#   0.9186742393220128],
#  [0.9031690406312552,
#   0.9776187023060541,
#   0.9351048575235219,
#   0.9369205631557054,
#   0.9537093544620984,
#   0.949597785259362,
#   0.9460548845324571,
#   0.815752729464699,
#   0.9689511697800208,
#   0.9365309340487]]

# %%
fig,(ax1, ax2)=  plt.subplots(1,2, figsize = (20,7))
box1 = ax1.boxplot(y1, labels = x,patch_artist = True)
# ax1.set_xlabel('Models with and without Grid Search')
# ax1.set_ylabel('R2 score')
ax1.set_title('Comparison of R2 scores', fontweight = 'bold', fontsize = 30)
ax1.set_xticklabels(ls, rotation = 90, fontsize = 30)
 
colors = ['darkgreen', 'darkgreen', 'purple', 'purple', 'crimson', 'crimson', 'blue', 'blue']
 
for patch, color in zip(box1['boxes'], colors):
    patch.set_facecolor(color)
 
ax1.grid()
box2 = ax2.boxplot(y2, labels = x,patch_artist = True)
# ax2.set_xlabel('Models with and without Grid Search')
# ax2.set_ylabel('Absolute Percentage Error')
ax2.set_title('Comparison of APE ', fontweight = 'bold', fontsize = 30)
ax2.set_xticklabels(ls, rotation = 90, fontsize = 30)
ax2.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

for patch, color in zip(box2['boxes'], colors):
    patch.set_facecolor(color)
ax2.grid()

plt.rc('font', size=30)

plt.savefig('grid_search_result.pdf', bbox_inches = 'tight')

# %%
r2_without_PCA = [np.mean(y1[0]) , np.mean(y1[2]) , np.mean(y1[4]), np.mean(y1[6])]
np.mean(r2_without_PCA)
# Out:
# 0.5721066631662755

# %%
r2_with_PCA = [np.mean(y1[1]) , np.mean(y1[3]) , np.mean(y1[5]), np.mean(y1[7])]
np.mean(r2_with_PCA)
# Out:
# 0.6872646648427339

# %%
mape_without_PCA = [np.median(y2[0]) , np.median(y2[2]) , np.median(y2[4]), np.median(y2[6])]
np.mean(mape_without_PCA)
# Out:
# 20.97106782516211

# %%
mape_with_PCA = [np.median(y2[1]) , np.median(y2[3]) , np.median(y2[5]), np.median(y2[7])]
np.mean(mape_with_PCA)
# Out:
# 16.658490605416127

# %%
mse_without_PCA = [np.mean(y3[0]) , np.mean(y3[2]) , np.mean(y3[4]), np.mean(y3[6])]
np.mean(mse_without_PCA)
# Out:
# 455117215.1413264
